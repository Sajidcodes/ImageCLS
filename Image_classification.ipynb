# %% [markdown]
# # HW3 Image Classification

# %% [markdown]
# # Check GPU Type

# %%
# !nvidia-smi
# Out:
# Wed Sep 27 01:04:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            Off  | 00000000:00:05.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Download Data

# %%
# !pip install gdown --upgrade
# Out:
# Requirement already satisfied: gdown in /opt/conda/lib/python3.10/site-packages (4.7.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=19ZlT0qm-3rdMRe60ya25xiN-ELOohr8M
# From (redirected): https://drive.google.com/uc?id=19ZlT0qm-3rdMRe60ya25xiN-ELOohr8M&confirm=t&uuid=9db31c2c-6d0c-4e49-a381-96c0f7b9c5a9
# To: /kaggle/working/data.zip
# 100%|███████████████████████████████████████| 1.03G/1.03G [00:08<00:00, 115MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !pip install gdown --upgrade
# Out:
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
# Successfully installed gdown-4.7.1
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=12sSrmByG2-QzkQn-JgnNEpkrAYsBPchD
# From (redirected): https://drive.google.com/uc?id=12sSrmByG2-QzkQn-JgnNEpkrAYsBPchD&confirm=t&uuid=bdfbdf2b-e1c8-4d5a-887a-de7642753130
# To: /kaggle/working/data.zip
# 100%|███████████████████████████████████████| 1.03G/1.03G [00:04<00:00, 223MB/s]

# %%
! unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: __MACOSX/._data
#    creating: data/valid/
#   inflating: __MACOSX/data/._valid
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#    creating: data/test/
#   inflating: __MACOSX/data/._test
#    creating: data/train/
#   inflating: __MACOSX/data/._train
#   inflating: data/valid/5_14.jpg
#   inflating: data/valid/5_209.jpg
#   inflating: data/valid/0_358.jpg
#   inflating: data/valid/5_28.jpg
#   inflating: data/valid/5_235.jpg
#   inflating: data/valid/8_202.jpg
#   inflating: data/valid/2_21.jpg
#   inflating: data/valid/10_6.jpg
#   inflating: data/valid/2_35.jpg
#   inflating: data/valid/8_216.jpg
#   inflating: data/valid/5_221.jpg
#   inflating: data/valid/3_258.jpg
#   inflating: data/valid/3_264.jpg
#   inflating: data/valid/3_270.jpg
#   inflating: data/valid/10_112.jpg
#   inflating: data/valid/8_54.jpg
#   inflating: data/valid/6_79.jpg
#   inflating: data/valid/4_218.jpg
#   inflating: data/valid/1_70.jpg
#   inflating: data/valid/1_64.jpg
#   inflating: data/valid/10_106.jpg
#   inflating: data/valid/8_40.jpg
#   inflating: data/valid/0_166.jpg
#   inflating: data/valid/8_68.jpg
#   inflating: data/valid/9_213.jpg
#   inflating: data/valid/6_45.jpg
#   inflating: data/valid/4_224.jpg
#   inflating: data/valid/10_16.jpg
#   inflating: data/valid/4_230.jpg
#   inflating: data/valid/1_58.jpg
#   inflating: data/valid/9_207.jpg
#   inflating: data/valid/6_51.jpg
#   inflating: data/valid/0_172.jpg
#   inflating: data/valid/2_249.jpg
#   inflating: data/valid/0_199.jpg
#   inflating: data/valid/8_97.jpg
#   inflating: data/valid/0_9.jpg
#   inflating: data/valid/8_83.jpg
#   inflating: data/valid/6_86.jpg
#   inflating: data/valid/2_275.jpg
#   inflating: data/valid/6_137.jpg
#   inflating: data/valid/6_123.jpg
#   inflating: data/valid/2_261.jpg
#   inflating: data/valid/6_92.jpg
#   inflating: data/valid/8_148.jpg
#   inflating: data/valid/3_75.jpg
#   inflating: data/valid/8_0.jpg
#   inflating: data/valid/2_498.jpg
#   inflating: data/valid/9_429.jpg
#   inflating: data/valid/4_68.jpg
#   inflating: data/valid/3_61.jpg
#   inflating: data/valid/3_49.jpg
#   inflating: data/valid/8_174.jpg
#   inflating: data/valid/9_367.jpg
#   inflating: data/valid/9_401.jpg
#   inflating: data/valid/5_143.jpg
#   inflating: data/valid/4_40.jpg
#   inflating: data/valid/5_157.jpg
#   inflating: data/valid/4_54.jpg
#   inflating: data/valid/9_415.jpg
#   inflating: data/valid/8_160.jpg
#   inflating: data/valid/9_373.jpg
#   inflating: data/valid/9_398.jpg
#   inflating: data/valid/2_329.jpg
#   inflating: data/valid/3_112.jpg
#   inflating: data/valid/2_301.jpg
#   inflating: data/valid/2_467.jpg
#   inflating: data/valid/4_83.jpg
#   inflating: data/valid/5_180.jpg
#   inflating: data/valid/2_473.jpg
#   inflating: data/valid/4_97.jpg
#   inflating: data/valid/5_194.jpg
#   inflating: data/valid/3_106.jpg
#   inflating: data/valid/2_315.jpg
#   inflating: data/valid/0_18.jpg
#   inflating: data/valid/7_11.jpg
#   inflating: data/valid/9_159.jpg
#   inflating: data/valid/9_28.jpg
#   inflating: data/valid/0_238.jpg
#   inflating: data/valid/5_369.jpg
#   inflating: data/valid/5_341.jpg
#   inflating: data/valid/4_152.jpg
#   inflating: data/valid/0_24.jpg
#   inflating: data/valid/9_165.jpg
#   inflating: data/valid/5_427.jpg
#   inflating: data/valid/0_210.jpg
#   inflating: data/valid/5_433.jpg
#   inflating: data/valid/0_204.jpg
#   inflating: data/valid/7_39.jpg
#   inflating: data/valid/9_171.jpg
#   inflating: data/valid/9_14.jpg
#   inflating: data/valid/0_30.jpg
#   inflating: data/valid/5_355.jpg
#   inflating: data/valid/4_146.jpg
#   inflating: data/valid/5_382.jpg
#   inflating: data/valid/4_191.jpg
#   inflating: data/valid/2_103.jpg
#   inflating: data/valid/3_310.jpg
#   inflating: data/valid/2_117.jpg
#   inflating: data/valid/3_304.jpg
#   inflating: data/valid/5_396.jpg
#   inflating: data/valid/4_185.jpg
#   inflating: data/valid/3_305.jpg
#   inflating: data/valid/2_116.jpg
#   inflating: data/valid/4_184.jpg
#   inflating: data/valid/5_397.jpg
#   inflating: data/valid/4_190.jpg
#   inflating: data/valid/5_383.jpg
#   inflating: data/valid/3_311.jpg
#   inflating: data/valid/2_102.jpg
#   inflating: data/valid/9_15.jpg
#   inflating: data/valid/9_170.jpg
#   inflating: data/valid/7_38.jpg
#   inflating: data/valid/0_205.jpg
#   inflating: data/valid/5_432.jpg
#   inflating: data/valid/4_147.jpg
#   inflating: data/valid/5_354.jpg
#   inflating: data/valid/0_31.jpg
#   inflating: data/valid/0_25.jpg
#   inflating: data/valid/4_153.jpg
#   inflating: data/valid/5_340.jpg
#   inflating: data/valid/0_211.jpg
#   inflating: data/valid/5_426.jpg
#   inflating: data/valid/9_164.jpg
#   inflating: data/valid/0_239.jpg
#   inflating: data/valid/9_29.jpg
#   inflating: data/valid/5_368.jpg
#   inflating: data/valid/0_19.jpg
#   inflating: data/valid/9_158.jpg
#   inflating: data/valid/7_10.jpg
#   inflating: data/valid/5_195.jpg
#   inflating: data/valid/4_96.jpg
#   inflating: data/valid/2_472.jpg
#   inflating: data/valid/2_314.jpg
#   inflating: data/valid/3_107.jpg
#   inflating: data/valid/2_300.jpg
#   inflating: data/valid/3_113.jpg
#   inflating: data/valid/5_181.jpg
#   inflating: data/valid/4_82.jpg
#   inflating: data/valid/2_466.jpg
#   inflating: data/valid/2_328.jpg
#   inflating: data/valid/9_399.jpg
#   inflating: data/valid/9_414.jpg
#   inflating: data/valid/4_55.jpg
#   inflating: data/valid/5_156.jpg
#   inflating: data/valid/9_372.jpg
#   inflating: data/valid/8_161.jpg
#   inflating: data/valid/9_366.jpg
#   inflating: data/valid/8_175.jpg
#   inflating: data/valid/3_48.jpg
#   inflating: data/valid/4_41.jpg
#   inflating: data/valid/5_142.jpg
#   inflating: data/valid/9_400.jpg
#   inflating: data/valid/4_69.jpg
#   inflating: data/valid/9_428.jpg
#   inflating: data/valid/3_60.jpg
#   inflating: data/valid/8_1.jpg
#   inflating: data/valid/3_74.jpg
#   inflating: data/valid/8_149.jpg
#   inflating: data/valid/2_499.jpg
#   inflating: data/valid/6_122.jpg
#   inflating: data/valid/6_93.jpg
#   inflating: data/valid/2_260.jpg
#   inflating: data/valid/2_274.jpg
#   inflating: data/valid/6_87.jpg
#   inflating: data/valid/6_136.jpg
#   inflating: data/valid/8_82.jpg
#   inflating: data/valid/8_96.jpg
#   inflating: data/valid/0_198.jpg
#   inflating: data/valid/2_248.jpg
#   inflating: data/valid/0_8.jpg
#   inflating: data/valid/1_59.jpg
#   inflating: data/valid/4_231.jpg
#   inflating: data/valid/10_17.jpg
#   inflating: data/valid/0_173.jpg
#   inflating: data/valid/6_50.jpg
#   inflating: data/valid/9_206.jpg
#   inflating: data/valid/6_44.jpg
#   inflating: data/valid/9_212.jpg
#   inflating: data/valid/8_69.jpg
#   inflating: data/valid/0_167.jpg
#   inflating: data/valid/4_225.jpg
#   inflating: data/valid/1_65.jpg
#   inflating: data/valid/10_107.jpg
#   inflating: data/valid/8_41.jpg
#   inflating: data/valid/6_78.jpg
#   inflating: data/valid/10_113.jpg
#   inflating: data/valid/8_55.jpg
#   inflating: data/valid/1_71.jpg
#   inflating: data/valid/4_219.jpg
#   inflating: data/valid/3_271.jpg
#   inflating: data/valid/3_265.jpg
#   inflating: data/valid/3_259.jpg
#   inflating: data/valid/8_217.jpg
#   inflating: data/valid/2_34.jpg
#   inflating: data/valid/5_220.jpg
#   inflating: data/valid/5_234.jpg
#   inflating: data/valid/5_29.jpg
#   inflating: data/valid/10_7.jpg
#   inflating: data/valid/2_20.jpg
#   inflating: data/valid/8_203.jpg
#   inflating: data/valid/5_208.jpg
#   inflating: data/valid/5_15.jpg
#   inflating: data/valid/0_359.jpg
#   inflating: data/valid/8_229.jpg
#   inflating: data/valid/3_298.jpg
#   inflating: data/valid/5_17.jpg
#   inflating: data/valid/5_222.jpg
#   inflating: data/valid/2_36.jpg
#   inflating: data/valid/8_215.jpg
#   inflating: data/valid/8_201.jpg
#   inflating: data/valid/2_22.jpg
#   inflating: data/valid/10_5.jpg
#   inflating: data/valid/5_236.jpg
#   inflating: data/valid/2_8.jpg
#   inflating: data/valid/3_273.jpg
#   inflating: data/valid/3_267.jpg
#   inflating: data/valid/10_105.jpg
#   inflating: data/valid/8_43.jpg
#   inflating: data/valid/9_238.jpg
#   inflating: data/valid/1_67.jpg
#   inflating: data/valid/10_29.jpg
#   inflating: data/valid/1_73.jpg
#   inflating: data/valid/10_111.jpg
#   inflating: data/valid/8_57.jpg
#   inflating: data/valid/0_159.jpg
#   inflating: data/valid/2_289.jpg
#   inflating: data/valid/10_139.jpg
#   inflating: data/valid/9_204.jpg
#   inflating: data/valid/6_52.jpg
#   inflating: data/valid/0_171.jpg
#   inflating: data/valid/10_15.jpg
#   inflating: data/valid/4_233.jpg
#   inflating: data/valid/4_227.jpg
#   inflating: data/valid/0_165.jpg
#   inflating: data/valid/9_210.jpg
#   inflating: data/valid/6_46.jpg
#   inflating: data/valid/8_80.jpg
#   inflating: data/valid/6_108.jpg
#   inflating: data/valid/8_94.jpg
#   inflating: data/valid/2_262.jpg
#   inflating: data/valid/6_91.jpg
#   inflating: data/valid/1_98.jpg
#   inflating: data/valid/6_120.jpg
#   inflating: data/valid/6_134.jpg
#   inflating: data/valid/6_85.jpg
#   inflating: data/valid/2_276.jpg
#   inflating: data/valid/3_62.jpg
#   inflating: data/valid/5_168.jpg
#   inflating: data/valid/9_358.jpg
#   inflating: data/valid/8_3.jpg
#   inflating: data/valid/3_76.jpg
#   inflating: data/valid/8_163.jpg
#   inflating: data/valid/9_370.jpg
#   inflating: data/valid/5_154.jpg
#   inflating: data/valid/4_57.jpg
#   inflating: data/valid/9_416.jpg
#   inflating: data/valid/9_402.jpg
#   inflating: data/valid/5_140.jpg
#   inflating: data/valid/4_43.jpg
#   inflating: data/valid/8_177.jpg
#   inflating: data/valid/9_364.jpg
#   inflating: data/valid/3_139.jpg
#   inflating: data/valid/2_458.jpg
#   inflating: data/valid/8_188.jpg
#   inflating: data/valid/3_105.jpg
#   inflating: data/valid/2_316.jpg
#   inflating: data/valid/2_470.jpg
#   inflating: data/valid/4_94.jpg
#   inflating: data/valid/5_197.jpg
#   inflating: data/valid/2_464.jpg
#   inflating: data/valid/4_80.jpg
#   inflating: data/valid/5_183.jpg
#   inflating: data/valid/3_111.jpg
#   inflating: data/valid/2_302.jpg
#   inflating: data/valid/3_89.jpg
#   inflating: data/valid/4_179.jpg
#   inflating: data/valid/5_418.jpg
#   inflating: data/valid/7_12.jpg
#   inflating: data/valid/0_33.jpg
#   inflating: data/valid/5_356.jpg
#   inflating: data/valid/4_145.jpg
#   inflating: data/valid/5_430.jpg
#   inflating: data/valid/0_207.jpg
#   inflating: data/valid/9_172.jpg
#   inflating: data/valid/9_17.jpg
#   inflating: data/valid/9_166.jpg
#   inflating: data/valid/5_424.jpg
#   inflating: data/valid/0_213.jpg
#   inflating: data/valid/5_342.jpg
#   inflating: data/valid/4_151.jpg
#   inflating: data/valid/0_27.jpg
#   inflating: data/valid/2_128.jpg
#   inflating: data/valid/9_199.jpg
#   inflating: data/valid/5_395.jpg
#   inflating: data/valid/4_186.jpg
#   inflating: data/valid/2_114.jpg
#   inflating: data/valid/3_307.jpg
#   inflating: data/valid/2_100.jpg
#   inflating: data/valid/3_313.jpg
#   inflating: data/valid/5_381.jpg
#   inflating: data/valid/4_192.jpg
#   inflating: data/valid/3_312.jpg
#   inflating: data/valid/2_101.jpg
#   inflating: data/valid/4_193.jpg
#   inflating: data/valid/5_380.jpg
#   inflating: data/valid/4_187.jpg
#   inflating: data/valid/5_394.jpg
#   inflating: data/valid/3_306.jpg
#   inflating: data/valid/2_115.jpg
#   inflating: data/valid/9_198.jpg
#   inflating: data/valid/2_129.jpg
#   inflating: data/valid/0_212.jpg
#   inflating: data/valid/5_425.jpg
#   inflating: data/valid/9_167.jpg
#   inflating: data/valid/0_26.jpg
#   inflating: data/valid/4_150.jpg
#   inflating: data/valid/5_343.jpg
#   inflating: data/valid/4_144.jpg
#   inflating: data/valid/5_357.jpg
#   inflating: data/valid/0_32.jpg
#   inflating: data/valid/9_16.jpg
#   inflating: data/valid/9_173.jpg
#   inflating: data/valid/0_206.jpg
#   inflating: data/valid/5_431.jpg
#   inflating: data/valid/7_13.jpg
#   inflating: data/valid/5_419.jpg
#   inflating: data/valid/4_178.jpg
#   inflating: data/valid/5_182.jpg
#   inflating: data/valid/4_81.jpg
#   inflating: data/valid/2_465.jpg
#   inflating: data/valid/3_88.jpg
#   inflating: data/valid/2_303.jpg
#   inflating: data/valid/3_110.jpg
#   inflating: data/valid/2_317.jpg
#   inflating: data/valid/3_104.jpg
#   inflating: data/valid/5_196.jpg
#   inflating: data/valid/4_95.jpg
#   inflating: data/valid/2_471.jpg
#   inflating: data/valid/2_459.jpg
#   inflating: data/valid/8_189.jpg
#   inflating: data/valid/3_138.jpg
#   inflating: data/valid/4_42.jpg
#   inflating: data/valid/5_141.jpg
#   inflating: data/valid/9_403.jpg
#   inflating: data/valid/9_365.jpg
#   inflating: data/valid/8_176.jpg
#   inflating: data/valid/9_371.jpg
#   inflating: data/valid/8_162.jpg
#   inflating: data/valid/9_417.jpg
#   inflating: data/valid/4_56.jpg
#   inflating: data/valid/5_155.jpg
#   inflating: data/valid/3_77.jpg
#   inflating: data/valid/8_2.jpg
#   inflating: data/valid/9_359.jpg
#   inflating: data/valid/3_63.jpg
#   inflating: data/valid/5_169.jpg
#   inflating: data/valid/6_135.jpg
#   inflating: data/valid/2_277.jpg
#   inflating: data/valid/6_84.jpg
#   inflating: data/valid/6_90.jpg
#   inflating: data/valid/2_263.jpg
#   inflating: data/valid/6_121.jpg
#   inflating: data/valid/1_99.jpg
#   inflating: data/valid/6_109.jpg
#   inflating: data/valid/8_95.jpg
#   inflating: data/valid/8_81.jpg
#   inflating: data/valid/4_226.jpg
#   inflating: data/valid/6_47.jpg
#   inflating: data/valid/9_211.jpg
#   inflating: data/valid/0_164.jpg
#   inflating: data/valid/0_170.jpg
#   inflating: data/valid/6_53.jpg
#   inflating: data/valid/9_205.jpg
#   inflating: data/valid/10_138.jpg
#   inflating: data/valid/4_232.jpg
#   inflating: data/valid/10_14.jpg
#   inflating: data/valid/1_72.jpg
#   inflating: data/valid/2_288.jpg
#   inflating: data/valid/0_158.jpg
#   inflating: data/valid/10_110.jpg
#   inflating: data/valid/8_56.jpg
#   inflating: data/valid/9_239.jpg
#   inflating: data/valid/10_104.jpg
#   inflating: data/valid/8_42.jpg
#   inflating: data/valid/10_28.jpg
#   inflating: data/valid/1_66.jpg
#   inflating: data/valid/3_266.jpg
#   inflating: data/valid/3_272.jpg
#   inflating: data/valid/2_9.jpg
#   inflating: data/valid/10_4.jpg
#   inflating: data/valid/2_23.jpg
#   inflating: data/valid/8_200.jpg
#   inflating: data/valid/5_237.jpg
#   inflating: data/valid/5_223.jpg
#   inflating: data/valid/8_214.jpg
#   inflating: data/valid/2_37.jpg
#   inflating: data/valid/3_299.jpg
#   inflating: data/valid/5_16.jpg
#   inflating: data/valid/8_228.jpg
#   inflating: data/valid/2_33.jpg
#   inflating: data/valid/8_210.jpg
#   inflating: data/valid/5_227.jpg
#   inflating: data/valid/5_233.jpg
#   inflating: data/valid/8_204.jpg
#   inflating: data/valid/10_0.jpg
#   inflating: data/valid/2_27.jpg
#   inflating: data/valid/3_289.jpg
#   inflating: data/valid/5_12.jpg
#   inflating: data/valid/8_238.jpg
#   inflating: data/valid/3_276.jpg
#   inflating: data/valid/3_262.jpg
#   inflating: data/valid/4_236.jpg
#   inflating: data/valid/10_10.jpg
#   inflating: data/valid/6_57.jpg
#   inflating: data/valid/9_201.jpg
#   inflating: data/valid/0_174.jpg
#   inflating: data/valid/0_160.jpg
#   inflating: data/valid/10_128.jpg
#   inflating: data/valid/6_43.jpg
#   inflating: data/valid/9_215.jpg
#   inflating: data/valid/4_222.jpg
#   inflating: data/valid/1_62.jpg
#   inflating: data/valid/0_148.jpg
#   inflating: data/valid/2_298.jpg
#   inflating: data/valid/10_100.jpg
#   inflating: data/valid/8_46.jpg
#   inflating: data/valid/10_114.jpg
#   inflating: data/valid/8_52.jpg
#   inflating: data/valid/9_229.jpg
#   inflating: data/valid/10_38.jpg
#   inflating: data/valid/1_76.jpg
#   inflating: data/valid/6_125.jpg
#   inflating: data/valid/2_267.jpg
#   inflating: data/valid/6_94.jpg
#   inflating: data/valid/6_80.jpg
#   inflating: data/valid/2_273.jpg
#   inflating: data/valid/6_131.jpg
#   inflating: data/valid/1_89.jpg
#   inflating: data/valid/6_119.jpg
#   inflating: data/valid/8_85.jpg
#   inflating: data/valid/8_91.jpg
#   inflating: data/valid/5_151.jpg
#   inflating: data/valid/4_52.jpg
#   inflating: data/valid/9_413.jpg
#   inflating: data/valid/9_375.jpg
#   inflating: data/valid/8_166.jpg
#   inflating: data/valid/9_361.jpg
#   inflating: data/valid/8_172.jpg
#   inflating: data/valid/9_407.jpg
#   inflating: data/valid/5_145.jpg
#   inflating: data/valid/4_46.jpg
#   inflating: data/valid/3_67.jpg
#   inflating: data/valid/9_349.jpg
#   inflating: data/valid/8_6.jpg
#   inflating: data/valid/3_73.jpg
#   inflating: data/valid/5_179.jpg
#   inflating: data/valid/4_91.jpg
#   inflating: data/valid/2_475.jpg
#   inflating: data/valid/5_192.jpg
#   inflating: data/valid/3_98.jpg
#   inflating: data/valid/2_313.jpg
#   inflating: data/valid/3_100.jpg
#   inflating: data/valid/2_307.jpg
#   inflating: data/valid/3_114.jpg
#   inflating: data/valid/4_85.jpg
#   inflating: data/valid/2_461.jpg
#   inflating: data/valid/5_186.jpg
#   inflating: data/valid/2_449.jpg
#   inflating: data/valid/8_199.jpg
#   inflating: data/valid/6_9.jpg
#   inflating: data/valid/3_128.jpg
#   inflating: data/valid/5_435.jpg
#   inflating: data/valid/0_202.jpg
#   inflating: data/valid/9_12.jpg
#   inflating: data/valid/9_177.jpg
#   inflating: data/valid/0_36.jpg
#   inflating: data/valid/4_140.jpg
#   inflating: data/valid/5_353.jpg
#   inflating: data/valid/4_154.jpg
#   inflating: data/valid/5_347.jpg
#   inflating: data/valid/0_22.jpg
#   inflating: data/valid/9_163.jpg
#   inflating: data/valid/5_421.jpg
#   inflating: data/valid/0_216.jpg
#   inflating: data/valid/5_409.jpg
#   inflating: data/valid/4_168.jpg
#   inflating: data/valid/7_17.jpg
#   inflating: data/valid/3_302.jpg
#   inflating: data/valid/2_111.jpg
#   inflating: data/valid/4_183.jpg
#   inflating: data/valid/5_390.jpg
#   inflating: data/valid/4_197.jpg
#   inflating: data/valid/5_384.jpg
#   inflating: data/valid/3_316.jpg
#   inflating: data/valid/2_105.jpg
#   inflating: data/valid/9_188.jpg
#   inflating: data/valid/2_139.jpg
#   inflating: data/valid/2_138.jpg
#   inflating: data/valid/9_189.jpg
#   inflating: data/valid/5_385.jpg
#   inflating: data/valid/4_196.jpg
#   inflating: data/valid/2_104.jpg
#   inflating: data/valid/3_317.jpg
#   inflating: data/valid/2_110.jpg
#   inflating: data/valid/3_303.jpg
#   inflating: data/valid/5_391.jpg
#   inflating: data/valid/4_182.jpg
#   inflating: data/valid/4_169.jpg
#   inflating: data/valid/7_16.jpg
#   inflating: data/valid/5_408.jpg
#   inflating: data/valid/0_23.jpg
#   inflating: data/valid/5_346.jpg
#   inflating: data/valid/4_155.jpg
#   inflating: data/valid/0_217.jpg
#   inflating: data/valid/5_420.jpg
#   inflating: data/valid/9_162.jpg
#   inflating: data/valid/9_176.jpg
#   inflating: data/valid/9_13.jpg
#   inflating: data/valid/0_203.jpg
#   inflating: data/valid/5_434.jpg
#   inflating: data/valid/5_352.jpg
#   inflating: data/valid/4_141.jpg
#   inflating: data/valid/0_37.jpg
#   inflating: data/valid/3_129.jpg
#   inflating: data/valid/2_448.jpg
#   inflating: data/valid/6_8.jpg
#   inflating: data/valid/8_198.jpg
#   inflating: data/valid/3_115.jpg
#   inflating: data/valid/2_306.jpg
#   inflating: data/valid/5_187.jpg
#   inflating: data/valid/2_460.jpg
#   inflating: data/valid/4_84.jpg
#   inflating: data/valid/5_193.jpg
#   inflating: data/valid/2_474.jpg
#   inflating: data/valid/4_90.jpg
#   inflating: data/valid/3_101.jpg
#   inflating: data/valid/2_312.jpg
#   inflating: data/valid/3_99.jpg
#   inflating: data/valid/3_72.jpg
#   inflating: data/valid/8_7.jpg
#   inflating: data/valid/5_178.jpg
#   inflating: data/valid/9_348.jpg
#   inflating: data/valid/3_66.jpg
#   inflating: data/valid/8_173.jpg
#   inflating: data/valid/9_360.jpg
#   inflating: data/valid/4_47.jpg
#   inflating: data/valid/5_144.jpg
#   inflating: data/valid/9_406.jpg
#   inflating: data/valid/9_412.jpg
#   inflating: data/valid/4_53.jpg
#   inflating: data/valid/5_150.jpg
#   inflating: data/valid/8_167.jpg
#   inflating: data/valid/9_374.jpg
#   inflating: data/valid/8_90.jpg
#   inflating: data/valid/6_118.jpg
#   inflating: data/valid/8_84.jpg
#   inflating: data/valid/2_272.jpg
#   inflating: data/valid/6_81.jpg
#   inflating: data/valid/1_88.jpg
#   inflating: data/valid/6_130.jpg
#   inflating: data/valid/6_124.jpg
#   inflating: data/valid/6_95.jpg
#   inflating: data/valid/2_266.jpg
#   inflating: data/valid/9_228.jpg
#   inflating: data/valid/10_115.jpg
#   inflating: data/valid/8_53.jpg
#   inflating: data/valid/1_77.jpg
#   inflating: data/valid/10_39.jpg
#   inflating: data/valid/1_63.jpg
#   inflating: data/valid/10_101.jpg
#   inflating: data/valid/8_47.jpg
#   inflating: data/valid/2_299.jpg
#   inflating: data/valid/0_149.jpg
#   inflating: data/valid/9_214.jpg
#   inflating: data/valid/6_42.jpg
#   inflating: data/valid/10_129.jpg
#   inflating: data/valid/0_161.jpg
#   inflating: data/valid/4_223.jpg
#   inflating: data/valid/10_11.jpg
#   inflating: data/valid/4_237.jpg
#   inflating: data/valid/0_175.jpg
#   inflating: data/valid/9_200.jpg
#   inflating: data/valid/6_56.jpg
#   inflating: data/valid/3_263.jpg
#   inflating: data/valid/3_277.jpg
#   inflating: data/valid/5_13.jpg
#   inflating: data/valid/8_239.jpg
#   inflating: data/valid/3_288.jpg
#   inflating: data/valid/5_232.jpg
#   inflating: data/valid/2_26.jpg
#   inflating: data/valid/10_1.jpg
#   inflating: data/valid/8_205.jpg
#   inflating: data/valid/8_211.jpg
#   inflating: data/valid/2_32.jpg
#   inflating: data/valid/5_226.jpg
#   inflating: data/valid/8_207.jpg
#   inflating: data/valid/0_361.jpg
#   inflating: data/valid/10_3.jpg
#   inflating: data/valid/2_24.jpg
#   inflating: data/valid/5_230.jpg
#   inflating: data/valid/5_224.jpg
#   inflating: data/valid/5_39.jpg
#   inflating: data/valid/2_30.jpg
#   inflating: data/valid/8_213.jpg
#   inflating: data/valid/2_18.jpg
#   inflating: data/valid/5_11.jpg
#   inflating: data/valid/5_218.jpg
#   inflating: data/valid/0_349.jpg
#   inflating: data/valid/3_261.jpg
#   inflating: data/valid/3_275.jpg
#   inflating: data/valid/3_249.jpg
#   inflating: data/valid/1_49.jpg
#   inflating: data/valid/4_221.jpg
#   inflating: data/valid/0_163.jpg
#   inflating: data/valid/6_40.jpg
#   inflating: data/valid/9_216.jpg
#   inflating: data/valid/8_79.jpg
#   inflating: data/valid/6_54.jpg
#   inflating: data/valid/9_202.jpg
#   inflating: data/valid/0_177.jpg
#   inflating: data/valid/4_235.jpg
#   inflating: data/valid/10_13.jpg
#   inflating: data/valid/1_75.jpg
#   inflating: data/valid/10_117.jpg
#   inflating: data/valid/8_51.jpg
#   inflating: data/valid/10_103.jpg
#   inflating: data/valid/8_45.jpg
#   inflating: data/valid/6_68.jpg
#   inflating: data/valid/1_61.jpg
#   inflating: data/valid/4_209.jpg
#   inflating: data/valid/6_132.jpg
#   inflating: data/valid/6_83.jpg
#   inflating: data/valid/2_270.jpg
#   inflating: data/valid/2_264.jpg
#   inflating: data/valid/6_97.jpg
#   inflating: data/valid/6_126.jpg
#   inflating: data/valid/8_92.jpg
#   inflating: data/valid/8_86.jpg
#   inflating: data/valid/2_258.jpg
#   inflating: data/valid/0_188.jpg
#   inflating: data/valid/9_404.jpg
#   inflating: data/valid/5_146.jpg
#   inflating: data/valid/4_45.jpg
#   inflating: data/valid/9_362.jpg
#   inflating: data/valid/8_171.jpg
#   inflating: data/valid/9_376.jpg
#   inflating: data/valid/8_165.jpg
#   inflating: data/valid/3_58.jpg
#   inflating: data/valid/5_152.jpg
#   inflating: data/valid/4_51.jpg
#   inflating: data/valid/9_410.jpg
#   inflating: data/valid/4_79.jpg
#   inflating: data/valid/9_438.jpg
#   inflating: data/valid/3_70.jpg
#   inflating: data/valid/8_5.jpg
#   inflating: data/valid/3_64.jpg
#   inflating: data/valid/8_159.jpg
#   inflating: data/valid/2_489.jpg
#   inflating: data/valid/4_86.jpg
#   inflating: data/valid/2_462.jpg
#   inflating: data/valid/5_185.jpg
#   inflating: data/valid/2_304.jpg
#   inflating: data/valid/3_117.jpg
#   inflating: data/valid/2_310.jpg
#   inflating: data/valid/3_103.jpg
#   inflating: data/valid/4_92.jpg
#   inflating: data/valid/2_476.jpg
#   inflating: data/valid/5_191.jpg
#   inflating: data/valid/2_338.jpg
#   inflating: data/valid/9_389.jpg
#   inflating: data/valid/7_28.jpg
#   inflating: data/valid/9_160.jpg
#   inflating: data/valid/5_422.jpg
#   inflating: data/valid/0_215.jpg
#   inflating: data/valid/4_157.jpg
#   inflating: data/valid/5_344.jpg
#   inflating: data/valid/0_21.jpg
#   inflating: data/valid/0_35.jpg
#   inflating: data/valid/4_143.jpg
#   inflating: data/valid/5_350.jpg
#   inflating: data/valid/5_436.jpg
#   inflating: data/valid/0_201.jpg
#   inflating: data/valid/9_11.jpg
#   inflating: data/valid/9_174.jpg
#   inflating: data/valid/0_229.jpg
#   inflating: data/valid/7_14.jpg
#   inflating: data/valid/9_39.jpg
#   inflating: data/valid/5_378.jpg
#   inflating: data/valid/9_148.jpg
#   inflating: data/valid/3_315.jpg
#   inflating: data/valid/2_106.jpg
#   inflating: data/valid/4_194.jpg
#   inflating: data/valid/5_387.jpg
#   inflating: data/valid/4_180.jpg
#   inflating: data/valid/5_393.jpg
#   inflating: data/valid/3_301.jpg
#   inflating: data/valid/2_112.jpg
#   inflating: data/valid/4_8.jpg
#   inflating: data/valid/4_9.jpg
#   inflating: data/valid/5_392.jpg
#   inflating: data/valid/4_181.jpg
#   inflating: data/valid/2_113.jpg
#   inflating: data/valid/3_300.jpg
#   inflating: data/valid/2_107.jpg
#   inflating: data/valid/3_314.jpg
#   inflating: data/valid/5_386.jpg
#   inflating: data/valid/4_195.jpg
#   inflating: data/valid/9_149.jpg
#   inflating: data/valid/9_38.jpg
#   inflating: data/valid/7_15.jpg
#   inflating: data/valid/0_228.jpg
#   inflating: data/valid/5_379.jpg
#   inflating: data/valid/5_351.jpg
#   inflating: data/valid/4_142.jpg
#   inflating: data/valid/0_34.jpg
#   inflating: data/valid/9_175.jpg
#   inflating: data/valid/9_10.jpg
#   inflating: data/valid/0_200.jpg
#   inflating: data/valid/5_437.jpg
#   inflating: data/valid/0_214.jpg
#   inflating: data/valid/5_423.jpg
#   inflating: data/valid/9_161.jpg
#   inflating: data/valid/7_29.jpg
#   inflating: data/valid/0_20.jpg
#   inflating: data/valid/5_345.jpg
#   inflating: data/valid/4_156.jpg
#   inflating: data/valid/9_388.jpg
#   inflating: data/valid/2_339.jpg
#   inflating: data/valid/3_102.jpg
#   inflating: data/valid/2_311.jpg
#   inflating: data/valid/5_190.jpg
#   inflating: data/valid/2_477.jpg
#   inflating: data/valid/4_93.jpg
#   inflating: data/valid/5_184.jpg
#   inflating: data/valid/2_463.jpg
#   inflating: data/valid/4_87.jpg
#   inflating: data/valid/3_116.jpg
#   inflating: data/valid/2_305.jpg
#   inflating: data/valid/8_158.jpg
#   inflating: data/valid/3_65.jpg
#   inflating: data/valid/2_488.jpg
#   inflating: data/valid/9_439.jpg
#   inflating: data/valid/4_78.jpg
#   inflating: data/valid/8_4.jpg
#   inflating: data/valid/3_71.jpg
#   inflating: data/valid/3_59.jpg
#   inflating: data/valid/8_164.jpg
#   inflating: data/valid/9_377.jpg
#   inflating: data/valid/9_411.jpg
#   inflating: data/valid/4_50.jpg
#   inflating: data/valid/5_153.jpg
#   inflating: data/valid/4_44.jpg
#   inflating: data/valid/5_147.jpg
#   inflating: data/valid/9_405.jpg
#   inflating: data/valid/8_170.jpg
#   inflating: data/valid/9_363.jpg
#   inflating: data/valid/0_189.jpg
#   inflating: data/valid/2_259.jpg
#   inflating: data/valid/8_87.jpg
#   inflating: data/valid/8_93.jpg
#   inflating: data/valid/6_96.jpg
#   inflating: data/valid/2_265.jpg
#   inflating: data/valid/6_127.jpg
#   inflating: data/valid/6_133.jpg
#   inflating: data/valid/2_271.jpg
#   inflating: data/valid/6_82.jpg
#   inflating: data/valid/6_69.jpg
#   inflating: data/valid/10_102.jpg
#   inflating: data/valid/8_44.jpg
#   inflating: data/valid/4_208.jpg
#   inflating: data/valid/1_60.jpg
#   inflating: data/valid/1_74.jpg
#   inflating: data/valid/10_116.jpg
#   inflating: data/valid/8_50.jpg
#   inflating: data/valid/0_176.jpg
#   inflating: data/valid/9_203.jpg
#   inflating: data/valid/6_55.jpg
#   inflating: data/valid/8_78.jpg
#   inflating: data/valid/10_12.jpg
#   inflating: data/valid/4_234.jpg
#   inflating: data/valid/4_220.jpg
#   inflating: data/valid/1_48.jpg
#   inflating: data/valid/9_217.jpg
#   inflating: data/valid/6_41.jpg
#   inflating: data/valid/0_162.jpg
#   inflating: data/valid/3_248.jpg
#   inflating: data/valid/3_274.jpg
#   inflating: data/valid/3_260.jpg
#   inflating: data/valid/5_219.jpg
#   inflating: data/valid/0_348.jpg
#   inflating: data/valid/2_19.jpg
#   inflating: data/valid/5_10.jpg
#   inflating: data/valid/5_38.jpg
#   inflating: data/valid/5_225.jpg
#   inflating: data/valid/8_212.jpg
#   inflating: data/valid/2_31.jpg
#   inflating: data/valid/2_25.jpg
#   inflating: data/valid/10_2.jpg
#   inflating: data/valid/0_360.jpg
#   inflating: data/valid/8_206.jpg
#   inflating: data/valid/5_231.jpg
#   inflating: data/valid/1_128.jpg
#   inflating: data/valid/5_77.jpg
#   inflating: data/valid/5_63.jpg
#   inflating: data/valid/8_249.jpg
#   inflating: data/valid/1_114.jpg
#   inflating: data/valid/0_307.jpg
#   inflating: data/valid/2_42.jpg
#   inflating: data/valid/8_261.jpg
#   inflating: data/valid/5_256.jpg
#   inflating: data/valid/5_242.jpg
#   inflating: data/valid/8_275.jpg
#   inflating: data/valid/1_100.jpg
#   inflating: data/valid/0_313.jpg
#   inflating: data/valid/2_56.jpg
#   inflating: data/valid/2_81.jpg
#   inflating: data/valid/3_207.jpg
#   inflating: data/valid/5_88.jpg
#   inflating: data/valid/5_295.jpg
#   inflating: data/valid/5_281.jpg
#   inflating: data/valid/2_95.jpg
#   inflating: data/valid/3_213.jpg
#   inflating: data/valid/1_13.jpg
#   inflating: data/valid/0_139.jpg
#   inflating: data/valid/10_171.jpg
#   inflating: data/valid/8_37.jpg
#   inflating: data/valid/10_165.jpg
#   inflating: data/valid/8_23.jpg
#   inflating: data/valid/9_258.jpg
#   inflating: data/valid/9_3.jpg
#   inflating: data/valid/10_49.jpg
#   inflating: data/valid/10_61.jpg
#   inflating: data/valid/4_247.jpg
#   inflating: data/valid/9_270.jpg
#   inflating: data/valid/6_26.jpg
#   inflating: data/valid/0_105.jpg
#   inflating: data/valid/0_111.jpg
#   inflating: data/valid/10_159.jpg
#   inflating: data/valid/9_264.jpg
#   inflating: data/valid/6_32.jpg
#   inflating: data/valid/10_75.jpg
#   inflating: data/valid/4_253.jpg
#   inflating: data/valid/4_284.jpg
#   inflating: data/valid/2_216.jpg
#   inflating: data/valid/2_202.jpg
#   inflating: data/valid/4_290.jpg
#   inflating: data/valid/6_140.jpg
#   inflating: data/valid/3_16.jpg
#   inflating: data/valid/9_338.jpg
#   inflating: data/valid/2_389.jpg
#   inflating: data/valid/5_108.jpg
#   inflating: data/valid/5_120.jpg
#   inflating: data/valid/4_23.jpg
#   inflating: data/valid/9_462.jpg
#   inflating: data/valid/8_117.jpg
#   inflating: data/valid/9_304.jpg
#   inflating: data/valid/8_103.jpg
#   inflating: data/valid/9_310.jpg
#   inflating: data/valid/9_476.jpg
#   inflating: data/valid/5_134.jpg
#   inflating: data/valid/4_37.jpg
#   inflating: data/valid/2_438.jpg
#   inflating: data/valid/3_159.jpg
#   inflating: data/valid/9_489.jpg
#   inflating: data/valid/2_404.jpg
#   inflating: data/valid/3_171.jpg
#   inflating: data/valid/2_362.jpg
#   inflating: data/valid/3_165.jpg
#   inflating: data/valid/2_376.jpg
#   inflating: data/valid/2_410.jpg
#   inflating: data/valid/7_72.jpg
#   inflating: data/valid/10_207.jpg
#   inflating: data/valid/8_329.jpg
#   inflating: data/valid/4_119.jpg
#   inflating: data/valid/7_66.jpg
#   inflating: data/valid/10_213.jpg
#   inflating: data/valid/5_444.jpg
#   inflating: data/valid/0_273.jpg
#   inflating: data/valid/9_106.jpg
#   inflating: data/valid/9_63.jpg
#   inflating: data/valid/8_315.jpg
#   inflating: data/valid/0_47.jpg
#   inflating: data/valid/5_322.jpg
#   inflating: data/valid/4_131.jpg
#   inflating: data/valid/5_336.jpg
#   inflating: data/valid/4_125.jpg
#   inflating: data/valid/0_53.jpg
#   inflating: data/valid/9_112.jpg
#   inflating: data/valid/9_77.jpg
#   inflating: data/valid/8_301.jpg
#   inflating: data/valid/0_267.jpg
#   inflating: data/valid/3_8.jpg
#   inflating: data/valid/9_88.jpg
#   inflating: data/valid/2_148.jpg
#   inflating: data/valid/0_298.jpg
#   inflating: data/valid/2_160.jpg
#   inflating: data/valid/0_84.jpg
#   inflating: data/valid/0_90.jpg
#   inflating: data/valid/2_174.jpg
#   inflating: data/valid/0_91.jpg
#   inflating: data/valid/2_175.jpg
#   inflating: data/valid/2_161.jpg
#   inflating: data/valid/0_85.jpg
#   inflating: data/valid/3_9.jpg
#   inflating: data/valid/0_299.jpg
#   inflating: data/valid/2_149.jpg
#   inflating: data/valid/9_89.jpg
#   inflating: data/valid/0_52.jpg
#   inflating: data/valid/4_124.jpg
#   inflating: data/valid/5_337.jpg
#   inflating: data/valid/0_266.jpg
#   inflating: data/valid/8_300.jpg
#   inflating: data/valid/9_76.jpg
#   inflating: data/valid/9_113.jpg
#   inflating: data/valid/8_314.jpg
#   inflating: data/valid/9_62.jpg
#   inflating: data/valid/9_107.jpg
#   inflating: data/valid/0_272.jpg
#   inflating: data/valid/5_445.jpg
#   inflating: data/valid/4_130.jpg
#   inflating: data/valid/5_323.jpg
#   inflating: data/valid/0_46.jpg
#   inflating: data/valid/4_118.jpg
#   inflating: data/valid/10_212.jpg
#   inflating: data/valid/7_67.jpg
#   inflating: data/valid/8_328.jpg
#   inflating: data/valid/10_206.jpg
#   inflating: data/valid/7_73.jpg
#   inflating: data/valid/2_377.jpg
#   inflating: data/valid/3_164.jpg
#   inflating: data/valid/2_411.jpg
#   inflating: data/valid/2_405.jpg
#   inflating: data/valid/2_363.jpg
#   inflating: data/valid/3_170.jpg
#   inflating: data/valid/3_158.jpg
#   inflating: data/valid/9_488.jpg
#   inflating: data/valid/2_439.jpg
#   inflating: data/valid/9_311.jpg
#   inflating: data/valid/8_102.jpg
#   inflating: data/valid/4_36.jpg
#   inflating: data/valid/5_135.jpg
#   inflating: data/valid/9_477.jpg
#   inflating: data/valid/9_463.jpg
#   inflating: data/valid/4_22.jpg
#   inflating: data/valid/5_121.jpg
#   inflating: data/valid/9_305.jpg
#   inflating: data/valid/8_116.jpg
#   inflating: data/valid/2_388.jpg
#   inflating: data/valid/5_109.jpg
#   inflating: data/valid/9_339.jpg
#   inflating: data/valid/3_17.jpg
#   inflating: data/valid/2_203.jpg
#   inflating: data/valid/6_141.jpg
#   inflating: data/valid/4_291.jpg
#   inflating: data/valid/4_285.jpg
#   inflating: data/valid/2_217.jpg
#   inflating: data/valid/6_33.jpg
#   inflating: data/valid/9_265.jpg
#   inflating: data/valid/10_158.jpg
#   inflating: data/valid/0_110.jpg
#   inflating: data/valid/4_252.jpg
#   inflating: data/valid/10_74.jpg
#   inflating: data/valid/4_246.jpg
#   inflating: data/valid/10_60.jpg
#   inflating: data/valid/0_104.jpg
#   inflating: data/valid/6_27.jpg
#   inflating: data/valid/9_271.jpg
#   inflating: data/valid/9_2.jpg
#   inflating: data/valid/9_259.jpg
#   inflating: data/valid/10_164.jpg
#   inflating: data/valid/8_22.jpg
#   inflating: data/valid/10_48.jpg
#   inflating: data/valid/1_12.jpg
#   inflating: data/valid/10_170.jpg
#   inflating: data/valid/8_36.jpg
#   inflating: data/valid/0_138.jpg
#   inflating: data/valid/5_280.jpg
#   inflating: data/valid/3_212.jpg
#   inflating: data/valid/2_94.jpg
#   inflating: data/valid/3_206.jpg
#   inflating: data/valid/2_80.jpg
#   inflating: data/valid/5_294.jpg
#   inflating: data/valid/5_89.jpg
#   inflating: data/valid/5_243.jpg
#   inflating: data/valid/2_57.jpg
#   inflating: data/valid/0_312.jpg
#   inflating: data/valid/1_101.jpg
#   inflating: data/valid/8_274.jpg
#   inflating: data/valid/8_260.jpg
#   inflating: data/valid/2_43.jpg
#   inflating: data/valid/0_306.jpg
#   inflating: data/valid/1_115.jpg
#   inflating: data/valid/5_257.jpg
#   inflating: data/valid/5_62.jpg
#   inflating: data/valid/8_248.jpg
#   inflating: data/valid/1_129.jpg
#   inflating: data/valid/5_76.jpg
#   inflating: data/valid/2_69.jpg
#   inflating: data/valid/5_60.jpg
#   inflating: data/valid/5_74.jpg
#   inflating: data/valid/5_269.jpg
#   inflating: data/valid/0_338.jpg
#   inflating: data/valid/8_276.jpg
#   inflating: data/valid/1_103.jpg
#   inflating: data/valid/0_310.jpg
#   inflating: data/valid/2_55.jpg
#   inflating: data/valid/5_241.jpg
#   inflating: data/valid/5_48.jpg
#   inflating: data/valid/5_255.jpg
#   inflating: data/valid/1_117.jpg
#   inflating: data/valid/0_304.jpg
#   inflating: data/valid/2_41.jpg
#   inflating: data/valid/8_262.jpg
#   inflating: data/valid/8_289.jpg
#   inflating: data/valid/3_238.jpg
#   inflating: data/valid/2_96.jpg
#   inflating: data/valid/3_210.jpg
#   inflating: data/valid/5_282.jpg
#   inflating: data/valid/5_296.jpg
#   inflating: data/valid/2_82.jpg
#   inflating: data/valid/3_204.jpg
#   inflating: data/valid/10_166.jpg
#   inflating: data/valid/8_20.jpg
#   inflating: data/valid/9_0.jpg
#   inflating: data/valid/10_172.jpg
#   inflating: data/valid/8_34.jpg
#   inflating: data/valid/6_19.jpg
#   inflating: data/valid/1_10.jpg
#   inflating: data/valid/4_278.jpg
#   inflating: data/valid/1_38.jpg
#   inflating: data/valid/10_76.jpg
#   inflating: data/valid/4_250.jpg
#   inflating: data/valid/0_112.jpg
#   inflating: data/valid/9_267.jpg
#   inflating: data/valid/6_31.jpg
#   inflating: data/valid/9_273.jpg
#   inflating: data/valid/6_25.jpg
#   inflating: data/valid/0_106.jpg
#   inflating: data/valid/10_62.jpg
#   inflating: data/valid/4_244.jpg
#   inflating: data/valid/10_89.jpg
#   inflating: data/valid/9_298.jpg
#   inflating: data/valid/2_229.jpg
#   inflating: data/valid/6_143.jpg
#   inflating: data/valid/4_293.jpg
#   inflating: data/valid/10_199.jpg
#   inflating: data/valid/2_201.jpg
#   inflating: data/valid/2_215.jpg
#   inflating: data/valid/4_287.jpg
#   inflating: data/valid/4_318.jpg
#   inflating: data/valid/9_449.jpg
#   inflating: data/valid/3_199.jpg
#   inflating: data/valid/3_15.jpg
#   inflating: data/valid/8_128.jpg
#   inflating: data/valid/9_475.jpg
#   inflating: data/valid/4_324.jpg
#   inflating: data/valid/5_137.jpg
#   inflating: data/valid/4_34.jpg
#   inflating: data/valid/8_100.jpg
#   inflating: data/valid/9_313.jpg
#   inflating: data/valid/8_114.jpg
#   inflating: data/valid/9_307.jpg
#   inflating: data/valid/3_29.jpg
#   inflating: data/valid/5_123.jpg
#   inflating: data/valid/4_20.jpg
#   inflating: data/valid/9_461.jpg
#   inflating: data/valid/1_9.jpg
#   inflating: data/valid/2_349.jpg
#   inflating: data/valid/2_413.jpg
#   inflating: data/valid/3_166.jpg
#   inflating: data/valid/2_375.jpg
#   inflating: data/valid/3_172.jpg
#   inflating: data/valid/2_361.jpg
#   inflating: data/valid/2_407.jpg
#   inflating: data/valid/0_258.jpg
#   inflating: data/valid/2_188.jpg
#   inflating: data/valid/10_210.jpg
#   inflating: data/valid/7_65.jpg
#   inflating: data/valid/9_48.jpg
#   inflating: data/valid/5_309.jpg
#   inflating: data/valid/0_78.jpg
#   inflating: data/valid/10_204.jpg
#   inflating: data/valid/7_71.jpg
#   inflating: data/valid/9_139.jpg
#   inflating: data/valid/7_59.jpg
#   inflating: data/valid/9_111.jpg
#   inflating: data/valid/8_302.jpg
#   inflating: data/valid/9_74.jpg
#   inflating: data/valid/0_264.jpg
#   inflating: data/valid/5_335.jpg
#   inflating: data/valid/4_126.jpg
#   inflating: data/valid/0_50.jpg
#   inflating: data/valid/0_44.jpg
#   inflating: data/valid/5_321.jpg
#   inflating: data/valid/4_132.jpg
#   inflating: data/valid/5_447.jpg
#   inflating: data/valid/0_270.jpg
#   inflating: data/valid/9_105.jpg
#   inflating: data/valid/8_316.jpg
#   inflating: data/valid/9_60.jpg
#   inflating: data/valid/2_177.jpg
#   inflating: data/valid/0_93.jpg
#   inflating: data/valid/0_87.jpg
#   inflating: data/valid/2_163.jpg
#   inflating: data/valid/0_86.jpg
#   inflating: data/valid/2_162.jpg
#   inflating: data/valid/2_176.jpg
#   inflating: data/valid/0_92.jpg
#   inflating: data/valid/4_133.jpg
#   inflating: data/valid/5_320.jpg
#   inflating: data/valid/0_45.jpg
#   inflating: data/valid/9_61.jpg
#   inflating: data/valid/8_317.jpg
#   inflating: data/valid/9_104.jpg
#   inflating: data/valid/0_271.jpg
#   inflating: data/valid/5_446.jpg
#   inflating: data/valid/0_265.jpg
#   inflating: data/valid/9_75.jpg
#   inflating: data/valid/8_303.jpg
#   inflating: data/valid/9_110.jpg
#   inflating: data/valid/7_58.jpg
#   inflating: data/valid/0_51.jpg
#   inflating: data/valid/4_127.jpg
#   inflating: data/valid/5_334.jpg
#   inflating: data/valid/0_79.jpg
#   inflating: data/valid/9_138.jpg
#   inflating: data/valid/7_70.jpg
#   inflating: data/valid/10_205.jpg
#   inflating: data/valid/9_49.jpg
#   inflating: data/valid/7_64.jpg
#   inflating: data/valid/10_211.jpg
#   inflating: data/valid/2_189.jpg
#   inflating: data/valid/0_259.jpg
#   inflating: data/valid/5_308.jpg
#   inflating: data/valid/2_360.jpg
#   inflating: data/valid/3_173.jpg
#   inflating: data/valid/2_406.jpg
#   inflating: data/valid/2_412.jpg
#   inflating: data/valid/2_374.jpg
#   inflating: data/valid/3_167.jpg
#   inflating: data/valid/1_8.jpg
#   inflating: data/valid/2_348.jpg
#   inflating: data/valid/3_28.jpg
#   inflating: data/valid/9_306.jpg
#   inflating: data/valid/8_115.jpg
#   inflating: data/valid/9_460.jpg
#   inflating: data/valid/4_21.jpg
#   inflating: data/valid/5_122.jpg
#   inflating: data/valid/4_35.jpg
#   inflating: data/valid/5_136.jpg
#   inflating: data/valid/4_325.jpg
#   inflating: data/valid/9_474.jpg
#   inflating: data/valid/9_312.jpg
#   inflating: data/valid/8_101.jpg
#   inflating: data/valid/8_129.jpg
#   inflating: data/valid/3_14.jpg
#   inflating: data/valid/9_448.jpg
#   inflating: data/valid/4_319.jpg
#   inflating: data/valid/3_198.jpg
#   inflating: data/valid/2_214.jpg
#   inflating: data/valid/4_286.jpg
#   inflating: data/valid/4_292.jpg
#   inflating: data/valid/6_142.jpg
#   inflating: data/valid/2_200.jpg
#   inflating: data/valid/10_198.jpg
#   inflating: data/valid/2_228.jpg
#   inflating: data/valid/10_88.jpg
#   inflating: data/valid/9_299.jpg
#   inflating: data/valid/0_107.jpg
#   inflating: data/valid/6_24.jpg
#   inflating: data/valid/9_272.jpg
#   inflating: data/valid/4_245.jpg
#   inflating: data/valid/10_63.jpg
#   inflating: data/valid/4_251.jpg
#   inflating: data/valid/10_77.jpg
#   inflating: data/valid/1_39.jpg
#   inflating: data/valid/6_30.jpg
#   inflating: data/valid/9_266.jpg
#   inflating: data/valid/0_113.jpg
#   inflating: data/valid/6_18.jpg
#   inflating: data/valid/10_173.jpg
#   inflating: data/valid/8_35.jpg
#   inflating: data/valid/4_279.jpg
#   inflating: data/valid/1_11.jpg
#   inflating: data/valid/9_1.jpg
#   inflating: data/valid/10_167.jpg
#   inflating: data/valid/8_21.jpg
#   inflating: data/valid/5_297.jpg
#   inflating: data/valid/3_205.jpg
#   inflating: data/valid/2_83.jpg
#   inflating: data/valid/3_211.jpg
#   inflating: data/valid/2_97.jpg
#   inflating: data/valid/5_283.jpg
#   inflating: data/valid/3_239.jpg
#   inflating: data/valid/8_288.jpg
#   inflating: data/valid/5_254.jpg
#   inflating: data/valid/5_49.jpg
#   inflating: data/valid/8_263.jpg
#   inflating: data/valid/2_40.jpg
#   inflating: data/valid/0_305.jpg
#   inflating: data/valid/1_116.jpg
#   inflating: data/valid/2_54.jpg
#   inflating: data/valid/0_311.jpg
#   inflating: data/valid/1_102.jpg
#   inflating: data/valid/8_277.jpg
#   inflating: data/valid/5_240.jpg
#   inflating: data/valid/5_268.jpg
#   inflating: data/valid/5_75.jpg
#   inflating: data/valid/0_339.jpg
#   inflating: data/valid/2_68.jpg
#   inflating: data/valid/5_61.jpg
#   inflating: data/valid/5_244.jpg
#   inflating: data/valid/5_59.jpg
#   inflating: data/valid/8_273.jpg
#   inflating: data/valid/0_315.jpg
#   inflating: data/valid/1_106.jpg
#   inflating: data/valid/2_50.jpg
#   inflating: data/valid/0_301.jpg
#   inflating: data/valid/1_112.jpg
#   inflating: data/valid/2_44.jpg
#   inflating: data/valid/8_267.jpg
#   inflating: data/valid/5_250.jpg
#   inflating: data/valid/5_278.jpg
#   inflating: data/valid/5_65.jpg
#   inflating: data/valid/0_329.jpg
#   inflating: data/valid/2_78.jpg
#   inflating: data/valid/5_71.jpg
#   inflating: data/valid/5_287.jpg
#   inflating: data/valid/2_93.jpg
#   inflating: data/valid/3_215.jpg
#   inflating: data/valid/2_87.jpg
#   inflating: data/valid/3_201.jpg
#   inflating: data/valid/5_293.jpg
#   inflating: data/valid/3_229.jpg
#   inflating: data/valid/5_8.jpg
#   inflating: data/valid/8_298.jpg
#   inflating: data/valid/0_117.jpg
#   inflating: data/valid/8_19.jpg
#   inflating: data/valid/6_34.jpg
#   inflating: data/valid/9_262.jpg
#   inflating: data/valid/4_255.jpg
#   inflating: data/valid/10_73.jpg
#   inflating: data/valid/4_241.jpg
#   inflating: data/valid/10_67.jpg
#   inflating: data/valid/1_29.jpg
#   inflating: data/valid/6_20.jpg
#   inflating: data/valid/9_276.jpg
#   inflating: data/valid/0_103.jpg
#   inflating: data/valid/10_163.jpg
#   inflating: data/valid/8_25.jpg
#   inflating: data/valid/9_5.jpg
#   inflating: data/valid/4_269.jpg
#   inflating: data/valid/1_15.jpg
# ...
#   inflating: data/train/2_319.jpg
#   inflating: data/train/5_826.jpg
#   inflating: data/train/9_1055.jpg
#   inflating: data/train/3_86.jpg
#   inflating: data/train/5_832.jpg
#   inflating: data/train/8_805.jpg
#   inflating: data/train/3_678.jpg
#   inflating: data/train/0_963.jpg
#   inflating: data/train/5_403.jpg
#   inflating: data/train/4_610.jpg
#   inflating: data/train/0_234.jpg
#   inflating: data/train/8_352.jpg
#   inflating: data/train/5_1147.jpg
#   inflating: data/train/9_24.jpg
#   inflating: data/train/9_141.jpg
#   inflating: data/train/9_627.jpg
#   inflating: data/train/8_434.jpg
#   inflating: data/train/2_1308.jpg
#   inflating: data/train/2_682.jpg
#   inflating: data/train/0_552.jpg
#   inflating: data/train/3_491.jpg
#   inflating: data/train/4_176.jpg
#   inflating: data/train/5_365.jpg
#   inflating: data/train/2_696.jpg
#   inflating: data/train/0_546.jpg
#   inflating: data/train/3_485.jpg
#   inflating: data/train/4_162.jpg
#   inflating: data/train/5_371.jpg
#   inflating: data/train/9_633.jpg
#   inflating: data/train/8_420.jpg
#   inflating: data/train/0_14.jpg
#   inflating: data/train/10_268.jpg
#   inflating: data/train/8_346.jpg
#   inflating: data/train/9_30.jpg
#   inflating: data/train/5_1153.jpg
#   inflating: data/train/9_155.jpg
#   inflating: data/train/5_417.jpg
#   inflating: data/train/4_604.jpg
#   inflating: data/train/0_220.jpg
#   inflating: data/train/10_240.jpg
#   inflating: data/train/2_1452.jpg
#   inflating: data/train/7_35.jpg
#   inflating: data/train/9_18.jpg
#   inflating: data/train/9_1280.jpg
#   inflating: data/train/0_208.jpg
#   inflating: data/train/2_866.jpg
#   inflating: data/train/5_359.jpg
#   inflating: data/train/8_408.jpg
#   inflating: data/train/2_1334.jpg
#   inflating: data/train/10_526.jpg
#   inflating: data/train/10_532.jpg
#   inflating: data/train/2_1320.jpg
#   inflating: data/train/0_28.jpg
#   inflating: data/train/2_872.jpg
#   inflating: data/train/9_1294.jpg
#   inflating: data/train/4_638.jpg
#   inflating: data/train/2_1446.jpg
#   inflating: data/train/10_254.jpg
#   inflating: data/train/7_21.jpg
#   inflating: data/train/9_169.jpg
#   inflating: data/train/8_391.jpg
#   inflating: data/train/5_1184.jpg
#   inflating: data/train/9_182.jpg
#   inflating: data/train/3_334.jpg
#   inflating: data/train/2_127.jpg
#   inflating: data/train/4_1.jpg
#   inflating: data/train/2_899.jpg
#   inflating: data/train/6_265.jpg
#   inflating: data/train/2_641.jpg
#   inflating: data/train/0_591.jpg
#   inflating: data/train/3_452.jpg
#   inflating: data/train/9_828.jpg
#   inflating: data/train/6_271.jpg
#   inflating: data/train/2_655.jpg
#   inflating: data/train/0_585.jpg
#   inflating: data/train/3_446.jpg
#   inflating: data/train/3_320.jpg
#   inflating: data/train/2_133.jpg
#   inflating: data/train/8_385.jpg
#   inflating: data/train/5_1190.jpg
#   inflating: data/train/9_196.jpg
#   inflating: data/train/3_308.jpg
#   inflating: data/train/4_837.jpg
#   inflating: data/train/9_1243.jpg
#   inflating: data/train/10_283.jpg
#   inflating: data/train/2_1491.jpg
#   inflating: data/train/9_800.jpg
#   inflating: data/train/6_259.jpg
#   inflating: data/train/4_189.jpg
#   inflating: data/train/2_669.jpg
#   inflating: data/train/9_814.jpg
#   inflating: data/train/2_1485.jpg
#   inflating: data/train/10_297.jpg
#   inflating: data/train/4_823.jpg
#   inflating: data/train/9_1257.jpg
#   inflating: data/train/9_815.jpg
#   inflating: data/train/2_668.jpg
#   inflating: data/train/9_1256.jpg
#   inflating: data/train/4_822.jpg
#   inflating: data/train/10_296.jpg
#   inflating: data/train/2_1484.jpg
#   inflating: data/train/2_1490.jpg
#   inflating: data/train/10_282.jpg
#   inflating: data/train/9_1242.jpg
#   inflating: data/train/4_836.jpg
#   inflating: data/train/3_309.jpg
#   inflating: data/train/4_188.jpg
#   inflating: data/train/6_258.jpg
#   inflating: data/train/9_801.jpg
#   inflating: data/train/3_447.jpg
#   inflating: data/train/0_584.jpg
#   inflating: data/train/2_654.jpg
#   inflating: data/train/6_270.jpg
#   inflating: data/train/9_829.jpg
#   inflating: data/train/9_197.jpg
#   inflating: data/train/5_1191.jpg
#   inflating: data/train/8_384.jpg
#   inflating: data/train/2_132.jpg
#   inflating: data/train/3_321.jpg
#   inflating: data/train/4_0.jpg
#   inflating: data/train/2_126.jpg
#   inflating: data/train/3_335.jpg
#   inflating: data/train/9_183.jpg
#   inflating: data/train/5_1185.jpg
#   inflating: data/train/8_390.jpg
#   inflating: data/train/3_453.jpg
#   inflating: data/train/0_590.jpg
#   inflating: data/train/2_640.jpg
#   inflating: data/train/6_264.jpg
#   inflating: data/train/2_898.jpg
#   inflating: data/train/2_873.jpg
#   inflating: data/train/0_29.jpg
#   inflating: data/train/2_1321.jpg
#   inflating: data/train/10_533.jpg
#   inflating: data/train/9_168.jpg
#   inflating: data/train/7_20.jpg
#   inflating: data/train/10_255.jpg
#   inflating: data/train/2_1447.jpg
#   inflating: data/train/4_639.jpg
#   inflating: data/train/9_1295.jpg
#   inflating: data/train/0_209.jpg
#   inflating: data/train/9_1281.jpg
#   inflating: data/train/9_19.jpg
#   inflating: data/train/7_34.jpg
#   inflating: data/train/2_1453.jpg
#   inflating: data/train/10_241.jpg
#   inflating: data/train/10_527.jpg
#   inflating: data/train/2_1335.jpg
#   inflating: data/train/8_409.jpg
#   inflating: data/train/5_358.jpg
#   inflating: data/train/2_867.jpg
#   inflating: data/train/0_15.jpg
#   inflating: data/train/8_421.jpg
#   inflating: data/train/9_632.jpg
#   inflating: data/train/5_370.jpg
#   inflating: data/train/4_163.jpg
#   inflating: data/train/3_484.jpg
#   inflating: data/train/0_547.jpg
#   inflating: data/train/2_697.jpg
#   inflating: data/train/0_221.jpg
#   inflating: data/train/4_605.jpg
#   inflating: data/train/5_416.jpg
#   inflating: data/train/9_154.jpg
#   inflating: data/train/5_1152.jpg
#   inflating: data/train/9_31.jpg
#   inflating: data/train/8_347.jpg
#   inflating: data/train/10_269.jpg
#   inflating: data/train/9_140.jpg
#   inflating: data/train/9_25.jpg
#   inflating: data/train/5_1146.jpg
#   inflating: data/train/8_353.jpg
#   inflating: data/train/0_235.jpg
#   inflating: data/train/4_611.jpg
#   inflating: data/train/5_402.jpg
#   inflating: data/train/5_364.jpg
#   inflating: data/train/4_177.jpg
#   inflating: data/train/3_490.jpg
#   inflating: data/train/0_553.jpg
#   inflating: data/train/2_683.jpg
#   inflating: data/train/2_1309.jpg
#   inflating: data/train/8_435.jpg
#   inflating: data/train/9_626.jpg
#   inflating: data/train/5_833.jpg
#   inflating: data/train/3_87.jpg
#   inflating: data/train/9_1054.jpg
#   inflating: data/train/0_962.jpg
#   inflating: data/train/3_679.jpg
#   inflating: data/train/8_804.jpg
#   inflating: data/train/8_810.jpg
#   inflating: data/train/0_976.jpg
#   inflating: data/train/7_249.jpg
#   inflating: data/train/5_199.jpg
#   inflating: data/train/5_827.jpg
#   inflating: data/train/2_318.jpg
#   inflating: data/train/3_93.jpg
#   inflating: data/train/9_1040.jpg
#   inflating: data/train/3_123.jpg
#   inflating: data/train/2_330.jpg
#   inflating: data/train/9_1068.jpg
#   inflating: data/train/8_186.jpg
#   inflating: data/train/9_395.jpg
#   inflating: data/train/8_838.jpg
#   inflating: data/train/7_261.jpg
#   inflating: data/train/2_456.jpg
#   inflating: data/train/0_786.jpg
#   inflating: data/train/3_645.jpg
#   inflating: data/train/3_889.jpg
#   inflating: data/train/7_275.jpg
#   inflating: data/train/2_442.jpg
#   inflating: data/train/0_792.jpg
#   inflating: data/train/3_651.jpg
#   inflating: data/train/8_192.jpg
#   inflating: data/train/9_381.jpg
#   inflating: data/train/3_137.jpg
#   inflating: data/train/2_324.jpg
#   inflating: data/train/6_2.jpg
#   inflating: data/train/5_628.jpg
#   inflating: data/train/9_1097.jpg
#   inflating: data/train/3_44.jpg
#   inflating: data/train/8_179.jpg
#   inflating: data/train/2_1123.jpg
#   inflating: data/train/0_779.jpg
#   inflating: data/train/3_862.jpg
#   inflating: data/train/4_59.jpg
#   inflating: data/train/4_349.jpg
#   inflating: data/train/3_876.jpg
#   inflating: data/train/9_418.jpg
#   inflating: data/train/2_1137.jpg
#   inflating: data/train/9_1083.jpg
#   inflating: data/train/1_218.jpg
#   inflating: data/train/3_50.jpg
#   inflating: data/train/8_145.jpg
#   inflating: data/train/9_356.jpg
#   inflating: data/train/5_614.jpg
#   inflating: data/train/4_407.jpg
#   inflating: data/train/1_230.jpg
#   inflating: data/train/3_78.jpg
#   inflating: data/train/2_495.jpg
#   inflating: data/train/0_745.jpg
#   inflating: data/train/3_686.jpg
#   inflating: data/train/4_71.jpg
#   inflating: data/train/4_361.jpg
#   inflating: data/train/5_172.jpg
#   inflating: data/train/9_430.jpg
#   inflating: data/train/8_623.jpg
#   inflating: data/train/9_424.jpg
#   inflating: data/train/8_637.jpg
#   inflating: data/train/2_481.jpg
#   inflating: data/train/0_751.jpg
#   inflating: data/train/3_692.jpg
#   inflating: data/train/4_65.jpg
#   inflating: data/train/4_375.jpg
#   inflating: data/train/0_989.jpg
#   inflating: data/train/5_166.jpg
#   inflating: data/train/5_600.jpg
#   inflating: data/train/4_413.jpg
#   inflating: data/train/1_224.jpg
#   inflating: data/train/8_151.jpg
#   inflating: data/train/9_342.jpg
#   inflating: data/train/9_1120.jpg
#   inflating: data/train/2_278.jpg
#   inflating: data/train/5_947.jpg
#   inflating: data/train/0_816.jpg
#   inflating: data/train/1_82.jpg
#   inflating: data/train/2_1094.jpg
#   inflating: data/train/10_686.jpg
#   inflating: data/train/1_96.jpg
#   inflating: data/train/10_692.jpg
#   inflating: data/train/2_1080.jpg
#   inflating: data/train/3_719.jpg
#   inflating: data/train/0_802.jpg
#   inflating: data/train/9_1134.jpg
#   inflating: data/train/4_598.jpg
#   inflating: data/train/5_953.jpg
#   inflating: data/train/2_244.jpg
#   inflating: data/train/0_194.jpg
#   inflating: data/train/1_387.jpg
#   inflating: data/train/8_794.jpg
#   inflating: data/train/9_587.jpg
#   inflating: data/train/3_731.jpg
#   inflating: data/train/2_522.jpg
#   inflating: data/train/0_4.jpg
#   inflating: data/train/6_106.jpg
#   inflating: data/train/3_725.jpg
#   inflating: data/train/2_536.jpg
#   inflating: data/train/6_112.jpg
#   inflating: data/train/8_780.jpg
#   inflating: data/train/9_593.jpg
#   inflating: data/train/9_1108.jpg
#   inflating: data/train/2_250.jpg
#   inflating: data/train/0_180.jpg
#   inflating: data/train/1_393.jpg
#   inflating: data/train/1_378.jpg
#   inflating: data/train/5_984.jpg
#   inflating: data/train/5_1218.jpg
#   inflating: data/train/6_48.jpg
#   inflating: data/train/10_123.jpg
#   inflating: data/train/8_65.jpg
#   inflating: data/train/2_1057.jpg
#   inflating: data/train/10_645.jpg
#   inflating: data/train/1_41.jpg
#   inflating: data/train/9_578.jpg
#   inflating: data/train/3_916.jpg
#   inflating: data/train/4_229.jpg
#   inflating: data/train/3_902.jpg
#   inflating: data/train/0_619.jpg
#   inflating: data/train/10_651.jpg
#   inflating: data/train/2_1043.jpg
#   inflating: data/train/1_55.jpg
#   inflating: data/train/10_137.jpg
#   inflating: data/train/8_71.jpg
#   inflating: data/train/5_990.jpg
#   inflating: data/train/5_748.jpg
#   inflating: data/train/9_222.jpg
#   inflating: data/train/6_74.jpg
#   inflating: data/train/5_1224.jpg
#   inflating: data/train/8_59.jpg
#   inflating: data/train/2_287.jpg
#   inflating: data/train/0_157.jpg
#   inflating: data/train/1_344.jpg
#   inflating: data/train/4_573.jpg
#   inflating: data/train/5_760.jpg
#   inflating: data/train/10_33.jpg
#   inflating: data/train/4_215.jpg
#   inflating: data/train/1_422.jpg
#   inflating: data/train/0_631.jpg
#   inflating: data/train/10_679.jpg
#   inflating: data/train/8_757.jpg
#   inflating: data/train/9_544.jpg
#   inflating: data/train/8_743.jpg
#   inflating: data/train/9_550.jpg
#   inflating: data/train/1_69.jpg
#   inflating: data/train/10_27.jpg
#   inflating: data/train/4_201.jpg
#   inflating: data/train/0_625.jpg
#   inflating: data/train/2_293.jpg
#   inflating: data/train/0_143.jpg
#   inflating: data/train/1_350.jpg
#   inflating: data/train/4_567.jpg
#   inflating: data/train/5_774.jpg
#   inflating: data/train/9_236.jpg
#   inflating: data/train/6_60.jpg
#   inflating: data/train/5_1230.jpg
#   inflating: data/train/9_961.jpg
#   inflating: data/train/10_484.jpg
#   inflating: data/train/2_1296.jpg
#   inflating: data/train/9_1444.jpg
#   inflating: data/train/6_338.jpg
#   inflating: data/train/3_269.jpg
#   inflating: data/train/9_1322.jpg
#   inflating: data/train/5_589.jpg
#   inflating: data/train/9_1336.jpg
#   inflating: data/train/9_1450.jpg
#   inflating: data/train/2_708.jpg
#   inflating: data/train/9_975.jpg
#   inflating: data/train/2_1282.jpg
#   inflating: data/train/10_490.jpg
#   inflating: data/train/2_6.jpg
#   inflating: data/train/6_304.jpg
#   inflating: data/train/9_1478.jpg
#   inflating: data/train/7_117.jpg
#   inflating: data/train/2_720.jpg
#   inflating: data/train/3_533.jpg
#   inflating: data/train/9_785.jpg
#   inflating: data/train/8_596.jpg
#   inflating: data/train/1_185.jpg
#   inflating: data/train/3_255.jpg
#   inflating: data/train/0_396.jpg
#   inflating: data/train/1_191.jpg
#   inflating: data/train/3_241.jpg
#   inflating: data/train/0_382.jpg
#   inflating: data/train/9_949.jpg
#   inflating: data/train/9_791.jpg
#   inflating: data/train/8_582.jpg
#   inflating: data/train/6_310.jpg
#   inflating: data/train/7_103.jpg
#   inflating: data/train/2_734.jpg
#   inflating: data/train/3_527.jpg
#   inflating: data/train/2_907.jpg
#   inflating: data/train/9_1487.jpg
#   inflating: data/train/5_25.jpg
#   inflating: data/train/5_238.jpg
#   inflating: data/train/8_569.jpg
#   inflating: data/train/10_447.jpg
#   inflating: data/train/2_1255.jpg
#   inflating: data/train/10_321.jpg
#   inflating: data/train/0_369.jpg
#   inflating: data/train/2_38.jpg
#   inflating: data/train/4_759.jpg
#   inflating: data/train/10_335.jpg
#   inflating: data/train/2_1241.jpg
#   inflating: data/train/10_453.jpg
#   inflating: data/train/2_913.jpg
#   inflating: data/train/5_31.jpg
#   inflating: data/train/9_1493.jpg
#   inflating: data/train/9_746.jpg
#   inflating: data/train/8_555.jpg
#   inflating: data/train/2_1269.jpg
#   inflating: data/train/0_433.jpg
#   inflating: data/train/5_19.jpg
#   inflating: data/train/5_204.jpg
#   inflating: data/train/5_562.jpg
#   inflating: data/train/2_10.jpg
#   inflating: data/train/4_771.jpg
#   inflating: data/train/1_146.jpg
#   inflating: data/train/3_296.jpg
#   inflating: data/train/0_355.jpg
#   inflating: data/train/5_1026.jpg
#   inflating: data/train/8_233.jpg
#   inflating: data/train/10_309.jpg
#   inflating: data/train/5_1032.jpg
#   inflating: data/train/8_227.jpg
#   inflating: data/train/5_576.jpg
#   inflating: data/train/4_765.jpg
#   inflating: data/train/1_152.jpg
#   inflating: data/train/3_282.jpg
#   inflating: data/train/0_341.jpg
#   inflating: data/train/0_427.jpg
#   inflating: data/train/5_210.jpg
#   inflating: data/train/9_752.jpg
#   inflating: data/train/8_541.jpg

# %% [markdown]
# # Import Packages

# %%
_exp_name = "sample"

# %%
# Import necessary packages.
import numpy as np
import pandas as pd
import torch
import os
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchvision.datasets import DatasetFolder, VisionDataset
# This is for the progress bar.
from tqdm.auto import tqdm
import torch

import random

# %%
def same_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

seed = 7777
same_seeds(seed)

# %% [markdown]
# # Transforms
# Torchvision provides lots of useful utilities for image preprocessing, data *wrapping* as well as data augmentation.
#
# Please refer to PyTorch official website for details about different transforms.

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    transforms.RandomRotation(30),  # Random rotation within [-15, 15] degrees
    transforms.RandomHorizontalFlip(.5),  # Randomly flip horizontally
    transforms.RandomVerticalFlip(.5),
    transforms.ColorJitter(brightness=0.6, contrast=0.6, saturation=0.6, hue=0.5),  # Adjust brightness, contrast, saturation, and hue
    transforms.RandomAffine(degrees=30, translate=(0.1, 0.1),scale=(0.8, 1.2), shear=15),  # Random affine transformation
  # Random affine transformation
    transforms.RandomResizedCrop(96, scale=(0.8, 1.0)),  # Random resized crop to 128x128
    transforms.GaussianBlur(kernel_size=5),

    # Cutout regularization (randomly mask out a portion of the image)
#     transforms.RandomErasing(p=0.5, scale=(0.02, 0.2), ratio=(0.3, 3.3)),

    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You may add some transforms here.

    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# # Datasets
# The data is labelled by the name, so we load images and label while calling '__getitem__'

# %%
class FoodDataset(Dataset):

    def __init__(self,path,tfm=test_tfm,files = None):
        super(FoodDataset).__init__()
        self.path = path
        self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".jpg")])
        if files != None:
            self.files = files

        self.transform = tfm

    def __len__(self):
        return len(self.files)

    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        im = self.transform(im)

        try:
            label = int(fname.split("/")[-1].split("_")[0])
        except:
            label = -1 # test has no label

        return im,label

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn

class ConvNet(nn.Module):
    def __init__(self, num_classes):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.25)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.25)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.25)
        )
        self.layer4 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Dropout(0.25)
        )
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, num_classes)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        return out

# Create the model
num_classes =11  # Replace with the number of classes in your dataset
model = ConvNet(num_classes)

# %% [markdown]
# # Configurations

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR
# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Initialize a model, and put it on the device specified.
model = ConvNet(num_classes).to(device)

# The number of batch size.
batch_size = 32

# The number of training epochs.
n_epochs = 13

# If no improvement in 'patience' epochs, early stop.
patience = 4

# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss()

# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=.0001)
scheduler = CosineAnnealingLR(optimizer, T_max=10)

# %% [markdown]
# # Dataloader

# %%
# Construct train and valid datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = FoodDataset("./data/train", tfm=train_tfm)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
valid_set = FoodDataset("./data/valid", tfm=test_tfm)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %% [markdown]
# # Start Training

# %%
import matplotlib.pyplot as plt

# Lists to store training and validation loss and accuracy values
train_losses = []
train_accuracies = []
valid_losses = []
valid_accuracies = []

# Initialize trackers, these are not parameters and should not be changed
stale = 0
best_acc = 0

for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []

    for batch in tqdm(train_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        #imgs = imgs.half()
        #print(imgs.shape,labels.shape)

        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs.to(device))

        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = criterion(logits, labels.to(device))

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # Compute the gradients for parameters.
        loss.backward()

        # Clip the gradient norms for stable training.
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc)

    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)

    # Print the information.
    print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")

    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in tqdm(valid_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        #imgs = imgs.half()

        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
            logits = model(imgs.to(device))

        # We can still compute the loss (but not the gradient).
        loss = criterion(logits, labels.to(device))

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc)
        #break

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)

    # Print the information.
    print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # update logs
    if valid_acc > best_acc:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f} -> best")
    else:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # save models
    if valid_acc > best_acc:
        print(f"Best model found at epoch {epoch}, saving model")
        torch.save(model.state_dict(), f"{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
        best_acc = valid_acc
        stale = 0
    else:
        stale += 1
        if stale > patience:
            print(f"No improvment {patience} consecutive epochs, early stopping")
            break

 # Append loss and accuracy values for plotting
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    valid_losses.append(valid_loss)
    valid_accuracies.append(valid_acc)

    scheduler.step()

# Plotting the training and validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, len(valid_losses) + 1), valid_losses, label='Valid Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

# Display the plots
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 001/013 ] loss = 2.30068, acc = 0.15119
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 001/013 ] loss = 2.28543, acc = 0.14786
# [ Valid | 001/013 ] loss = 2.28543, acc = 0.14786 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 002/013 ] loss = 2.28248, acc = 0.16891
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 002/013 ] loss = 2.26657, acc = 0.19223
# [ Valid | 002/013 ] loss = 2.26657, acc = 0.19223 -> best
# Best model found at epoch 1, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 003/013 ] loss = 2.27562, acc = 0.18046
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 003/013 ] loss = 2.24083, acc = 0.19628
# [ Valid | 003/013 ] loss = 2.24083, acc = 0.19628 -> best
# Best model found at epoch 2, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 004/013 ] loss = 2.26815, acc = 0.17787
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 004/013 ] loss = 2.23710, acc = 0.19676
# [ Valid | 004/013 ] loss = 2.23710, acc = 0.19676 -> best
# Best model found at epoch 3, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 005/013 ] loss = 2.25418, acc = 0.18451
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 005/013 ] loss = 2.23291, acc = 0.20930
# [ Valid | 005/013 ] loss = 2.23291, acc = 0.20930 -> best
# Best model found at epoch 4, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 006/013 ] loss = 2.22842, acc = 0.20601
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 006/013 ] loss = 2.17458, acc = 0.22155
# [ Valid | 006/013 ] loss = 2.17458, acc = 0.22155 -> best
# Best model found at epoch 5, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 007/013 ] loss = 2.21101, acc = 0.21157
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 007/013 ] loss = 2.14837, acc = 0.24142
# [ Valid | 007/013 ] loss = 2.14837, acc = 0.24142 -> best
# Best model found at epoch 6, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 008/013 ] loss = 2.18863, acc = 0.21612
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 008/013 ] loss = 2.11916, acc = 0.24875
# [ Valid | 008/013 ] loss = 2.11916, acc = 0.24875 -> best
# Best model found at epoch 7, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 009/013 ] loss = 2.17839, acc = 0.21911
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 009/013 ] loss = 2.10049, acc = 0.24981
# [ Valid | 009/013 ] loss = 2.10049, acc = 0.24981 -> best
# Best model found at epoch 8, saving model
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 010/013 ] loss = 2.16627, acc = 0.22514
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 010/013 ] loss = 2.09903, acc = 0.24489
# [ Valid | 010/013 ] loss = 2.09903, acc = 0.24489
#   0%|          | 0/309 [00:00<?, ?it/s]
# [ Train | 011/013 ] loss = 2.15898, acc = 0.22799
#   0%|          | 0/108 [00:00<?, ?it/s]
# [ Valid | 011/013 ] loss = 2.09879, acc = 0.24363
# [ Valid | 011/013 ] loss = 2.09879, acc = 0.24363
#   0%|          | 0/309 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 23
#      20 train_loss = []
#      21 train_accs = []
# ---> 23 for batch in tqdm(train_loader):
#      24
#      25     # A batch consists of image data and corresponding labels.
#      26     imgs, labels = batch
#      27     #imgs = imgs.half()
#      28     #print(imgs.shape,labels.shape)
#      29
#      30     # Forward the data. (Make sure data and model are on the same device.)
#
# File /opt/conda/lib/python3.10/site-packages/tqdm/notebook.py:249, in tqdm_notebook.__iter__(self)
#     247 try:
#     248     it = super(tqdm_notebook, self).__iter__()
# --> 249     for obj in it:
#     250         # return super(tqdm...) will not catch exception
#     251         yield obj
#     252 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /opt/conda/lib/python3.10/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[9], line 18, in FoodDataset.__getitem__(self, idx)
#      16 fname = self.files[idx]
#      17 im = Image.open(fname)
# ---> 18 im = self.transform(im)
#      20 try:
#      21     label = int(fname.split("/")[-1].split("_")[0])
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/transforms/transforms.py:1281, in ColorJitter.forward(self, img)
#    1279 for fn_id in fn_idx:
#    1280     if fn_id == 0 and brightness_factor is not None:
# -> 1281         img = F.adjust_brightness(img, brightness_factor)
#    1282     elif fn_id == 1 and contrast_factor is not None:
#    1283         img = F.adjust_contrast(img, contrast_factor)
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:893, in adjust_brightness(img, brightness_factor)
#     891     _log_api_usage_once(adjust_brightness)
#     892 if not isinstance(img, torch.Tensor):
# --> 893     return F_pil.adjust_brightness(img, brightness_factor)
#     895 return F_t.adjust_brightness(img, brightness_factor)
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/transforms/_functional_pil.py:73, in adjust_brightness(img, brightness_factor)
#      70     raise TypeError(f"img should be PIL Image. Got {type(img)}")
#      72 enhancer = ImageEnhance.Brightness(img)
# ---> 73 img = enhancer.enhance(brightness_factor)
#      74 return img
#
# File /opt/conda/lib/python3.10/site-packages/PIL/ImageEnhance.py:36, in _Enhance.enhance(self, factor)
#      25 def enhance(self, factor):
#      26     """
#      27     Returns an enhanced image.
#      28
#    (...)
#      34     :rtype: :py:class:`~PIL.Image.Image`
#      35     """
# ---> 36     return Image.blend(self.degenerate, self.image, factor)
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3340, in blend(im1, im2, alpha)
#    3338 im1.load()
#    3339 im2.load()
# -> 3340 return im1._new(core.blend(im1.im, im2.im, alpha))
#
# KeyboardInterrupt:

# %% [markdown]
# # Dataloader for test

# %%
# Construct test datasets.
# The argument "loader" tells how torchvision reads the data.
test_set = FoodDataset("./data/test", tfm=test_tfm)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # Testing and generate prediction CSV

# %%
model_best = ConvNet(num_classes).to(device)
model_best.load_state_dict(torch.load(f"{_exp_name}_best.ckpt"))
model_best.eval()
prediction = []
with torch.no_grad():
    for data,_ in tqdm(test_loader):
        test_pred = model_best(data.to(device))
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        prediction += test_label.squeeze().tolist()
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]

# %%
# create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(len(test_set))]
df["Label"] = prediction
df.to_csv("submission.csv",index = False)
